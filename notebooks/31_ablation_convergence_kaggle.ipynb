# %%
# 1. Reset to Kaggle working directory
# %cd /kaggle/working

# 2. Clone the latest codebase
# !rm -rf TF_Biding_Project
# !git clone https://github.com/JustinYuanZe/TF_Biding_Project.git
# %cd TF_Biding_Project

# 3. Install deps (einops for DNABERT-2; shap+seaborn for per-variant SHAP)
# !pip install -q einops shap seaborn

# 4. Run the CONVERGENCE ablation study (A1->A4 ladder, EPOCHS=30, PATIENCE=8).
#    Tests whether the no-bio variants (A1-A3) merely under-converged at 15 epochs.
#    Tip: to change the budget, edit cfg.EPOCHS / cfg.PATIENCE inside the .py first.
# !accelerate launch --mixed_precision=no --multi_gpu --num_processes=2 notebooks/31_ablation_convergence_kaggle.py

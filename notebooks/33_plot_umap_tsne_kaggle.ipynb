# %%
# 1. Reset to Kaggle working directory for path safety
# %cd /kaggle/working

# 2. Clean up existing directory and clone the latest codebase
# !rm -rf TF_Biding_Project
# !git clone https://github.com/JustinYuanZe/TF_Biding_Project.git

# 3. Navigate into the project directory
# %cd TF_Biding_Project

# 4. Install deps (einops for DNABERT-2; triton, umap-learn for projections)
# !pip install -q einops triton umap-learn seaborn

# 5. Run UMAP / t-SNE embedding projection script
# !python notebooks/33_plot_umap_tsne_kaggle.py

# %% [markdown]
# # DNABERT-2 Fine-Tuning Training Wrapper
# This notebook runs the standardized Multi-GPU fine-tuning script using Hugging Face Accelerate.

# %%
# Clone the repository
# !git clone https://github.com/JustinYuanZe/TF_Biding_Project.git
# %cd TF_Biding_Project

# %%
# Install dependencies silently
# !pip install -q einops

# %%
# Launch training on Multi-GPU
# !accelerate launch --mixed_precision=no --multi_gpu --num_processes=2 notebooks/10_dnabert2_finetune_kaggle.py

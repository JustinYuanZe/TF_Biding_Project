# %%
# Install required packages silently
# !pip install -q einops

# %%
# Launch the standardized script using accelerate on 2 GPUs
# !accelerate launch --mixed_precision=no --multi_gpu --num_processes=2 notebooks/15_kan_crossmodal_kaggle.py

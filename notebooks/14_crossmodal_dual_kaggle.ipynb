# %%
# 1. Reset về thư mục gốc của Kaggle để đảm bảo an toàn đường dẫn
# %cd /kaggle/working

# 2. Xóa thư mục cũ (nếu có) và clone bản mới nhất
# !rm -rf TF_Biding_Project
# !git clone https://github.com/JustinYuanZe/TF_Biding_Project.git

# 3. Chuyển vào thư mục dự án
# %cd TF_Biding_Project

# 4. Chỉ cài duy nhất einops để tránh xung đột thư viện gây lỗi đỏ
# !pip install -q einops
# !accelerate launch --mixed_precision=no --multi_gpu --num_processes=2 notebooks/14_crossmodal_dual_kaggle.py

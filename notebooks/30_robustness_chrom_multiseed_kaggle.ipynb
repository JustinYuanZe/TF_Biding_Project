# %%
# 1. Reset to Kaggle working directory for path safety
# %cd /kaggle/working

# 2. Clean up existing directory and clone the latest codebase
# !rm -rf TF_Biding_Project
# !git clone https://github.com/JustinYuanZe/TF_Biding_Project.git

# 3. Navigate into the project directory
# %cd TF_Biding_Project

# 4. Install deps (einops for DNABERT-2; seaborn for plotting)
# !pip install -q einops seaborn

# 5. Launch distributed robustness run (chromosome-holdout + multi-seed) on 2x GPUs
# !accelerate launch --mixed_precision=no --multi_gpu --num_processes=2 notebooks/30_robustness_chrom_multiseed_kaggle.py
